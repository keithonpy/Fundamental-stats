# %% [markdown]
# ## Motivation of Neural Network

# %% [markdown]
# Similar to Classification, classifer uses a mapping function (mapping for $\phi(x)$)
# $$
# \hat{y} = sign(\theta \cdot \phi(x))
# $$
# Neural network passes the linear function input to non-linear function called activation function

# %% [markdown]
# ## Activation function of neural network

# %% [markdown]
# 1. Linear function:
# $$
# f(Z) = Z
# $$
# 1. ReLU (Rectified linear unit):
# $$
# f(Z) = \begin{cases}
# Z & \text{if} Z > 0 \\
# 0 & \text{if} Z \leq 0
# \end{cases}
# $$
# 1. Hyperbolic tangent function:
# $$
# f(Z) = \frac{e^{Z} - e^{-Z}}{e^{Z} + e^{-Z}}
# $$

# %% [markdown]
# ## Reasons to use deep learning

# %% [markdown]
# 1. Lots of data
# 1. Improvement of computation
# 1. Large model are easier to train
# 1. Flexible neural lego piece

# %% [markdown]
# ## The NAND function and conversion

# %% [markdown]
# 1. The AND function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. The NOT function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. The OR function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Hidden Layer Model

# %% [markdown]
# For each layer in the neural network, there are a non-linear function. Neural network is composed of many linear function and then resample the data until it is linear separable.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In the above diagram, it could be imagined as two linear seperators(linear functions/ line lines). The output of layer 1 (or input to layer 2) could become linear separable as below:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# or couldn't be linear separable if it is with another activation function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# When there are more hidden layer units, they could be seperated.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Hyperparameter of neural network

# %% [markdown]
# ## Back-propagation algorithm
